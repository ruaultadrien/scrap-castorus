# %%
import datetime
import os

import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

# %%
base_url = 'https://www.castorus.com'

# %% [markdown]
# ### Get search url based on parameter search

# %% [markdown]
# radius_dic = {0: '', 5: 1, 10: 2, 15: 2, 30: 4}
# type_dic = {'house': 1, 'farm': 5, 'immeuble': 9}
#
# def build_search_url(location, radius, n_rooms, type_, price_min, price_max, min_m_2=0):
#     type_code = type_dic[type_]
#     radius_code = radius_dic[radius]
#
#     return f"https://www.castorus.com/s/{location[0]},{location[1]},{type_code}-{radius_code}-{min_m_2}--{price_min}-{price_max}-{n_rooms}----------------------"

# %% [markdown]
# ### Get dataframe based on search url

# %%
def get_dataframe_from_url(url, center, type_):
    ppties_dic = {'price': [], 'price_m2': [], 'date_in': [], 'title': [], 'link_castorus': [], 'n_rooms': [],
                  'surface': [], 'evolution': [], 'n_days_up': [], 'link_ad': [], 'center': [], 'type': []}
    
    res = requests.get(url)
    soup = BeautifulSoup(res.content)
    soup_res = soup.find('table', id='myTableResult')
    
    if soup_res == None:
        print('No data available...')
        return pd.DataFrame(ppties_dic)
    soup_res = soup_res.find('tbody')

    
    for res in tqdm(soup_res, desc='Iterating over properties'):
        ppties_dic['price'] += [int(res.find('td', {"class":'price'}).string)]

        pm2_classes = iter(['hide_mobile price', 'hide_mobile price green', 'hide_mobile price red'])
        pm2 = None
        while pm2 == None:
            curr_class = next(pm2_classes)
            pm2 = res.find('td', {"class": curr_class})
        ppties_dic['price_m2'] += [int(pm2.string)]

        parsed_date = res.find('span').string.split('/')
        d = [int(i) for i in parsed_date]
        ppties_dic['date_in'] += [datetime.datetime(year=int(d[2]), month=int(d[1]), day=int(d[0]))]

        title_field = res.find('td', {"class": 'title'})
        ppties_dic['title'] += [title_field.string]
        castorus_url = base_url + title_field.find('a')['href']
        ppties_dic['link_castorus'] += [castorus_url] 
        
        
        next_castorus_soup = BeautifulSoup(requests.get(castorus_url).content)
        link_element = next_castorus_soup.find('a', {'id': 'Redir_A'})
        if link_element == None:
            print('Link broken at castorus_url', castorus_url)
            print(ppties_dic['price'][-1], ppties_dic['title'][-1])
            ppties_dic['link_ad'] += [None]
        else:
            url_ad_redir = link_element['href']
            ppties_dic['link_ad'] += [base_url + '/' + url_ad_redir]
        

        ppties_dic['n_rooms'] += [res.find('td', {"class":'hide_mobile piece'}).string]

        ppties_dic['surface'] += [res.find('td', {"class":'surf'}).string]

        evol = res.find('td', {"class":'hide_mobile evol'}).string
        if evol != None and evol != 'stable':
            for char in ['(', ')', '%']:
                evol = evol.replace(char, '')
            evol = float(evol)
        else:
            evol = np.nan
        ppties_dic['evolution'] += [evol]

        ppties_dic['n_days_up'] += [res.find('td', {"class":'since'}).string]
        
        ppties_dic['center'] += [center]
        ppties_dic['type'] += [type_]
        
    return pd.DataFrame(ppties_dic)

# %% [markdown]
# ### Create Dataframe for multiple centers

# %%
def build_df_from_centers(centers, radius):
    types = ['house', 'immeuble', 'farm']
    df = pd.DataFrame()
    for c in tqdm(centers, desc='Iterating over centers'):
        print('Current center:', c)
        for type_ in types:
            target_url = build_search_url(c, radius=radius, n_rooms=10, type_=type_, 
                                          price_min=200000, price_max=1200000, min_m_2=200)
            print('Current url:', target_url)
            df_ = get_dataframe_from_url(target_url, c, type_)
            df = df.append(df_)
    return df

# %% [markdown]
# ### Scrap execution

# %%
centers = [('Angers', 19447), ('Nantes', 17969), ('Le+Mans', 31646), ('Tours', 15280)]
df = build_df_from_centers(centers, radius=30)
# Out:
# HBox(children=(IntProgress(value=0, description='Iterating over centers', max=4, style=ProgressStyle(descripti…
# Current center: ('Angers', 19447)
# Current url: https://www.castorus.com/s/Angers,19447,1-4-200--200000-1200000-10----------------------
# HBox(children=(IntProgress(value=0, description='Iterating over properties', max=225, style=ProgressStyle(desc…
# Current url: https://www.castorus.com/s/Angers,19447,9-4-200--200000-1200000-10----------------------
# HBox(children=(IntProgress(value=0, description='Iterating over properties', max=1, style=ProgressStyle(descri…
# Current url: https://www.castorus.com/s/Angers,19447,5-4-200--200000-1200000-10----------------------
# No data available...
# Current center: ('Nantes', 17969)
# Current url: https://www.castorus.com/s/Nantes,17969,1-4-200--200000-1200000-10----------------------
# HBox(children=(IntProgress(value=0, description='Iterating over properties', max=208, style=ProgressStyle(desc…
# Current url: https://www.castorus.com/s/Nantes,17969,9-4-200--200000-1200000-10----------------------
# HBox(children=(IntProgress(value=0, description='Iterating over properties', max=2, style=ProgressStyle(descri…
# Current url: https://www.castorus.com/s/Nantes,17969,5-4-200--200000-1200000-10----------------------
# No data available...
# Current center: ('Le+Mans', 31646)
# Current url: https://www.castorus.com/s/Le+Mans,31646,1-4-200--200000-1200000-10----------------------
# HBox(children=(IntProgress(value=0, description='Iterating over properties', max=168, style=ProgressStyle(desc…
# Current url: https://www.castorus.com/s/Le+Mans,31646,9-4-200--200000-1200000-10----------------------
# HBox(children=(IntProgress(value=0, description='Iterating over properties', max=3, style=ProgressStyle(descri…
# Current url: https://www.castorus.com/s/Le+Mans,31646,5-4-200--200000-1200000-10----------------------
# HBox(children=(IntProgress(value=0, description='Iterating over properties', max=2, style=ProgressStyle(descri…
# Current center: ('Tours', 15280)
# Current url: https://www.castorus.com/s/Tours,15280,1-4-200--200000-1200000-10----------------------
# HBox(children=(IntProgress(value=0, description='Iterating over properties', max=274, style=ProgressStyle(desc…
# Current url: https://www.castorus.com/s/Tours,15280,9-4-200--200000-1200000-10----------------------
# HBox(children=(IntProgress(value=0, description='Iterating over properties', max=5, style=ProgressStyle(descri…
# Current url: https://www.castorus.com/s/Tours,15280,5-4-200--200000-1200000-10----------------------
# No data available...

# %% [markdown]
# ### Postprocess

# %%
qu = df[df['n_days_up'].astype(int) > 365].sort_values('evolution')
qu.to_csv('365days_worstevo_castorus.csv')
qu
# Out:
#          price  price_m2    date_in                          title  \
# 76    850000.0    1704.0 2020-02-10  Propriété - 21 pièces, 499m2
# 270   680000.0    1943.0 2020-02-06  Propriété - 10 pièces, 350m2
# 4     884000.0     598.0 2020-01-29     Vends - 40 pièces, 1480m2
# 39    378500.0    1262.0 2020-02-11  Propriété - 14 pièces, 300m2
# 230   224000.0     688.0 2020-02-16  Propriété - 12 pièces, 326m2
# 125   516000.0    1362.0 2020-02-03  Propriété - 13 pièces, 379m2
# 133   635000.0    1717.0 2020-01-31  Propriété - 15 pièces, 370m2
# 71    519950.0    1188.0 2020-02-13  Propriété - 17 pièces, 438m2
# 173   219200.0    1049.0 2020-02-14  Propriété - 14 pièces, 209m2
# 91    470000.0    1045.0 2020-02-16  Propriété - 10 pièces, 450m2
# 27    439000.0    1585.0 2020-02-06  Propriété - 11 pièces, 277m2
# 181   373500.0    1245.0 2020-02-12  Propriété - 13 pièces, 300m2
# 82    397000.0    1909.0 2020-02-13  Propriété - 10 pièces, 208m2
# 187   370000.0    1234.0 2020-02-15  Propriété - 10 pièces, 300m2
# 176   370000.0    1226.0 2020-02-08  Propriété - 10 pièces, 302m2
# 264   541000.0    1691.0 2020-02-04  Propriété - 10 pièces, 320m2
# 76    478350.0    1544.0 2020-02-13  Propriété - 12 pièces, 310m2
# 173          https://www.castorus.com/angers,d65701693      14     209
# 91           https://www.castorus.com/nantes,d65641400      10     450
# 27           https://www.castorus.com/esvres,d65155718      11     277
# 181          https://www.castorus.com/angers,d58841999      13     300
# 82          https://www.castorus.com/le-mans,d65698034      10     208
# 187  https://www.castorus.com/la-chapelle-basse-mer...      10     300
# 176  https://www.castorus.com/st-julien-de-concelle...      10     302
# 264  https://www.castorus.com/rouziers-de-touraine,...      10     320
# 76          https://www.castorus.com/le-mans,d65358502      12     310
# 129         https://www.castorus.com/le-mans,d65698035      10     208
# 74          https://www.castorus.com/le-mans,d59000117      10     450
# 155     https://www.castorus.com/rochecorbon,d77566345      10     330
# 85           https://www.castorus.com/angers,d64159820      14     300
# 88           https://www.castorus.com/angers,d65421022      10     305
# 89           https://www.castorus.com/angers,d65700322      13     325
# 201  https://www.castorus.com/seiches-sur-le-loir,d...      15     230
# 8    https://www.castorus.com/la-chevroliere,d65877628      11     390
# 136          https://www.castorus.com/nantes,d75124652      14     635
# 152          https://www.castorus.com/nantes,d62811401      20     900
# 195      https://www.castorus.com/le-cellier,d47678499      12     301
# 196      https://www.castorus.com/le-cellier,d59751215      10     210
# 2              https://www.castorus.com/oize,d60168545      15     500
# 16   https://www.castorus.com/la-suze-sur-sarthe,d6...      10     260
# 37   https://www.castorus.com/chemire-le-gaudin,d50...      19     500
# 42   https://www.castorus.com/chemire-le-gaudin,d66...      18     490
# 58           https://www.castorus.com/change,d64829518      10     215
# 75          https://www.castorus.com/le-mans,d62635777      11     273
# 86          https://www.castorus.com/le-mans,d68502273      10     350
# 92          https://www.castorus.com/le-mans,d74133196      11     260
# 6         https://www.castorus.com/manthelan,d59691624      11     286
# 17          https://www.castorus.com/sorigny,d61322159      12     356
# 68      https://www.castorus.com/ballan-mire,d58201422      10     200
# 69      https://www.castorus.com/ballan-mire,d59299659      10     200
# 76      https://www.castorus.com/ballan-mire,d64706231      10     200
# 128           https://www.castorus.com/tours,d78037323      12     340
# 129           https://www.castorus.com/tours,d64716377      12     340
# 130           https://www.castorus.com/tours,d64803735      12     340
# 131           https://www.castorus.com/tours,d65599530      10     330
# 134           https://www.castorus.com/tours,d65979890      10     270
# 199           https://www.castorus.com/tours,d72082059      18     670
# 200           https://www.castorus.com/tours,d59321936      10     270
# 234  https://www.castorus.com/montlouis-sur-loire,d...      11     355
# 247  https://www.castorus.com/st-cyr-sur-loire,d616...      12     390
# 255        https://www.castorus.com/ambillou,d57473571      10     290
# 269      https://www.castorus.com/villedomer,d57374962      18     700
#
#      evolution n_days_up                                            link_ad
# 76      -28.57       555  https://www.castorus.com/r.php?redirect=d60261194
# 270     -28.42       616  https://www.castorus.com/r.php?redirect=d47800769
# 4       -22.59       379  https://www.castorus.com/r.php?redirect=d65098198
# 39      -19.98       466  https://www.castorus.com/r.php?redirect=d62701046
# 230     -18.55       429  https://www.castorus.com/r.php?redirect=d64165598
# 125     -18.10       810  https://www.castorus.com/r.php?redirect=d53513439
# 133     -15.33       754  https://www.castorus.com/r.php?redirect=d65372101
# 71      -13.04       507  https://www.castorus.com/r.php?redirect=d61423178
# 173     -12.28       370  https://www.castorus.com/r.php?redirect=d65701693
# 91      -10.48       370  https://www.castorus.com/r.php?redirect=d65641400
# 27      -10.04       389  https://www.castorus.com/r.php?redirect=d65155718
# 181      -9.87       597  https://www.castorus.com/r.php?redirect=d58841999
# 82       -7.67       369  https://www.castorus.com/r.php?redirect=d65698034
# 187      -6.49       373  https://www.castorus.com/r.php?redirect=d68158534
# 176      -6.33       374  https://www.castorus.com/r.php?redirect=d65468841
# 264      -5.01       458  https://www.castorus.com/r.php?redirect=d65053127
# 76       -3.95       388  https://www.castorus.com/r.php?redirect=d65358502
# 129      -3.51       369  https://www.castorus.com/r.php?redirect=d65698035
# 74       -2.51       593  https://www.castorus.com/r.php?redirect=d59000117
# 155      -1.58       564  https://www.castorus.com/r.php?redirect=d77566345
# 85         NaN       625  https://www.castorus.com/r.php?redirect=d64159820
# 88         NaN       375  https://www.castorus.com/r.php?redirect=d65421022
# 89         NaN       368  https://www.castorus.com/r.php?redirect=d65700322
# 201        NaN       383  https://www.castorus.com/r.php?redirect=d65013033
# 8          NaN       367  https://www.castorus.com/r.php?redirect=d65877628
# 136        NaN       411  https://www.castorus.com/r.php?redirect=d75124652
# 152        NaN       458  https://www.castorus.com/r.php?redirect=d62811401
# 195        NaN      1250  https://www.castorus.com/r.php?redirect=d47678499
# 196        NaN       570  https://www.castorus.com/r.php?redirect=d59751215
# 2          NaN       553  https://www.castorus.com/r.php?redirect=d60168545
# 16         NaN       520  https://www.castorus.com/r.php?redirect=d61013764
# 37         NaN       935  https://www.castorus.com/r.php?redirect=d50434407
# 42         NaN       935  https://www.castorus.com/r.php?redirect=d66368154
# 58         NaN       386  https://www.castorus.com/r.php?redirect=d64829518
# 75         NaN       464  https://www.castorus.com/r.php?redirect=d62635777
# 86         NaN       606  https://www.castorus.com/r.php?redirect=d68502273
# 92         NaN       400  https://www.castorus.com/r.php?redirect=d74133196
# 6          NaN       577  https://www.castorus.com/r.php?redirect=d59691624
# 17         NaN       515  https://www.castorus.com/r.php?redirect=d61322159
# 68         NaN       643  https://www.castorus.com/r.php?redirect=d58201422
# 69         NaN       607  https://www.castorus.com/r.php?redirect=d59299659
# 76         NaN       389  https://www.castorus.com/r.php?redirect=d64706231
# 128        NaN       389  https://www.castorus.com/r.php?redirect=d78037323
# 129        NaN       389  https://www.castorus.com/r.php?redirect=d64716377
# 130        NaN       386  https://www.castorus.com/r.php?redirect=d64803735
# 131        NaN       371  https://www.castorus.com/r.php?redirect=d65599530
# 134        NaN       586  https://www.castorus.com/r.php?redirect=d65979890
# 199        NaN       571  https://www.castorus.com/r.php?redirect=d72082059
# 200        NaN       586  https://www.castorus.com/r.php?redirect=d59321936
# 234        NaN       502  https://www.castorus.com/r.php?redirect=d59962148
# 247        NaN       500  https://www.castorus.com/r.php?redirect=d61659783
# 255        NaN       922  https://www.castorus.com/r.php?redirect=d57473571
# 269        NaN      1399  https://www.castorus.com/r.php?redirect=d57374962

# %%
df.sort_values()

# %%
df['n_days_up'].astype(int)
# Out:
# 0    146
# 1    102
# 2    101
# 3    199
# 4    360
#     ...
# 0    173
# 1     37
# 2     33
# 3     82
# 4    379
# Name: n_days_up, Length: 888, dtype: int64

# %%
df.to_csv('full_castorus.csv')
